# %% [markdown]
# # **Name:** Hamza Shafiq
# **Github:** [Hamza Shafiq](https://github.com/hamza811998)\
# **LinkedIn:** [Hamza Shafiq](https://www.linkedin.com/in/hamza811998/)\
# **Fiverr:** [Hamza Shafiq](https://www.fiverr.com/hamza_811998?up_rollout=true)\
# **Facebook:** [Hamza Shafiq](https://www.facebook.com/hamza811998/)\
# **Twitter:** [Hamza Shafiq](https://twitter.com/hamza811998)\
# **Instagram:** [Hamza Shafiq](https://www.instagram.com/hamza811998/)\
# **Email:** hamza811998shafiq@gmail.com

# %% [markdown]
# # TASK #1: PROJECT OVERVIEW

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # TASK #2: IMPORT LIBRARIES/DATASETS

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pandas as pd
import seaborn as sns
import pickle
import random

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open("./traffic-signs-data/train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("./traffic-signs-data/valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("./traffic-signs-data/test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']

# %%
X_train.shape
# Out:
# (34799, 32, 32, 3)

# %%
y_train.shape
# Out:
# (34799,)

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %% [markdown]
# # TASK #3: PERFORM IMAGES VISUALIZATION

# %%
i = np.random.randint(1, len(X_train))
plt.imshow(X_train[i])
y_train[i]
# Out:
# 11

# %%
# Let's view more images in a grid format
# Define the dimensions of the plot grid

# For visualize 5 by 5 matrix images
# W_grid = 5
# L_grid = 5

# For visualize 10 by 10 matrix images
W_grid = 10
L_grid = 10

# fig, axes = plt.subplots(L_grid, W_grid)
# subplot return the figure object and axes object
# we can use the axes object to plot specific figures at various locations

fig, axes = plt.subplots(L_grid, W_grid, figsize = (10,10))

axes = axes.ravel() # flaten the 5 x 5 matrix into 25 array

n_training = len(X_train) # get the length of the training dataset

# Select a random number from 0 to n_training
# create evenly spaces variables 
for i in np.arange(0, W_grid * L_grid):
    # Select a random number
    index = np.random.randint(0, n_training)
    # read and display an image with the selected index    
    axes[i].imshow(X_train[index])
    axes[i].set_title(y_train[index], fontsize = 15)
    axes[i].axis('off')

plt.subplots_adjust(wspace = 0.4, hspace = 0.4)

# %% [markdown]
# # TASK #4: CONVERT IMAGES TO GRAYSCALE AND PERFORM NORMALIZATION

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %%
X_train_gray = np.sum(X_train/3, axis = 3, keepdims = True)

# %%
X_train_gray.shape
# Out:
# (34799, 32, 32, 1)

# %%
X_train_gray_norm = (X_train_gray - 128)/128

# %%
X_train_gray_norm
# Out:
# array([[[[-0.36197917],
#          [-0.45833333],
#          [-0.65364583],
#          ...,
#          [-0.45572917],
#          [-0.50520833],
#          [-0.54947917]],
#
#         [[-0.38020833],
#          [-0.60677083],
#          [-0.69010417],
#          ...,
#          [-0.59375   ],
#          [-0.63541667],
#          [-0.68489583]],
#
#         [[-0.484375  ],
#          [-0.6953125 ],
#          [-0.6953125 ],
#          ...,
#          [-0.6171875 ],
#          [-0.63802083],
#          [-0.6796875 ]],
#
#         ...,
#
#         [[-0.11197917],
#          [-0.1875    ],
#          [-0.2734375 ],
#          ...,
#          [-0.16145833],
#          [-0.17708333],
#          [-0.14322917]],
#
#         [[-0.078125  ],
#          [-0.22395833],
#          [-0.17708333],
#          ...,
#          [-0.140625  ],
#          [-0.16666667],
#          [-0.17708333]],
#
#         [[ 0.078125  ],
#          [ 0.14583333],
#          [ 0.10416667],
#          ...,
#          [-0.12760417],
#          [-0.1328125 ],
#          [-0.16927083]]],
#
#
#        [[[-0.64583333],
#          [-0.63802083],
#          [-0.6328125 ],
#          ...,
#          [-0.53645833],
#          [-0.56510417],
#          [-0.609375  ]],
#
#         [[-0.6484375 ],
#          [-0.65625   ],
#          [-0.63541667],
#          ...,
#          [-0.5703125 ],
#          [-0.6171875 ],
#          [-0.59635417]],
#
#         [[-0.65104167],
#          [-0.66927083],
#          [-0.64583333],
#          ...,
#          [-0.5859375 ],
#          [-0.63802083],
#          [-0.61197917]],
#
#         ...,
#
#         [[-0.69010417],
#          [-0.69791667],
#          [-0.6953125 ],
#          ...,
#          [-0.6796875 ],
#          [-0.66927083],
#          [-0.67708333]],
#
#         [[-0.67708333],
#          [-0.70833333],
#          [-0.6796875 ],
#          ...,
#          [-0.66927083],
#          [-0.65104167],
#          [-0.66666667]],
#
#         [[-0.70052083],
#          [-0.71354167],
#          [-0.69791667],
#          ...,
#          [-0.66145833],
#          [-0.6796875 ],
#          [-0.66145833]]],
#
#
#        [[[-0.84895833],
#          [-0.859375  ],
#          [-0.85416667],
#          ...,
#          [-0.8046875 ],
#          [-0.82552083],
#          [-0.84114583]],
#
#         [[-0.82552083],
#          [-0.84114583],
#          [-0.8671875 ],
#          ...,
#          [-0.81770833],
#          [-0.83072917],
#          [-0.83854167]],
#
#         [[-0.82552083],
#          [-0.8359375 ],
#          [-0.84895833],
#          ...,
#          [-0.80208333],
#          [-0.80729167],
#          [-0.80989583]],
#
#         ...,
#
#         [[-0.8359375 ],
#          [-0.84375   ],
#          [-0.8515625 ],
#          ...,
#          [-0.83072917],
#          [-0.79947917],
#          [-0.80208333]],
#
#         [[-0.8359375 ],
#          [-0.8359375 ],
#          [-0.85416667],
#          ...,
#          [-0.83072917],
#          [-0.796875  ],
#          [-0.78385417]],
#
#         [[-0.84635417],
#          [-0.84375   ],
#          [-0.85416667],
#          ...,
#          [-0.8359375 ],
#          [-0.8046875 ],
#          [-0.80208333]]],
#
#
#        ...,
#
#
#        [[[-0.67708333],
#          [-0.68489583],
#          [-0.69010417],
#          ...,
#          [ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.9921875 ]],
#
#         [[-0.67708333],
#          [-0.68489583],
#          [-0.6875    ],
#          ...,
#          [ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.9921875 ]],
#
#         [[-0.70052083],
#          [-0.71614583],
#          [-0.734375  ],
#          ...,
#          [ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.9921875 ]],
#
#         ...,
#
#         [[ 0.46875   ],
#          [ 0.46614583],
#          [ 0.46875   ],
#          ...,
#          [ 0.95052083],
#          [ 0.8125    ],
#          [ 0.80729167]],
#
#         [[ 0.49479167],
#          [ 0.5       ],
#          [ 0.51302083],
#          ...,
#          [ 0.88020833],
#          [ 0.48177083],
#          [ 0.44270833]],
#
#         [[ 0.5234375 ],
#          [ 0.52604167],
#          [ 0.54166667],
#          ...,
#          [ 0.953125  ],
#          [ 0.7890625 ],
#          [ 0.78125   ]]],
#
#
#        [[[ 0.03385417],
#          [ 0.04166667],
#          [ 0.04947917],
#          ...,
#          [-0.08854167],
#          [-0.0703125 ],
#          [-0.05989583]],
#
#         [[-0.01822917],
#          [-0.01041667],
#          [-0.0078125 ],
#          ...,
#          [-0.02864583],
#          [-0.015625  ],
#          [ 0.        ]],
#
#         [[-0.04947917],
#          [-0.04427083],
#          [-0.04427083],
#          ...,
#          [ 0.01041667],
#          [ 0.00520833],
#          [ 0.015625  ]],
#
#         ...,
#
#         [[-0.81510417],
#          [-0.8203125 ],
#          [-0.8203125 ],
#          ...,
#          [-0.84114583],
#          [-0.83333333],
#          [-0.84114583]],
#
#         [[-0.828125  ],
#          [-0.83333333],
#          [-0.828125  ],
#          ...,
#          [-0.84375   ],
#          [-0.8359375 ],
#          [-0.8359375 ]],
#
#         [[-0.8359375 ],
#          [-0.83854167],
#          [-0.83072917],
#          ...,
#          [-0.84114583],
#          [-0.83854167],
#          [-0.84375   ]]],
#
#
#        [[[-0.76041667],
#          [-0.765625  ],
#          [-0.765625  ],
#          ...,
#          [-0.7734375 ],
#          [-0.76822917],
#          [-0.75260417]],
#
#         [[-0.75520833],
#          [-0.75520833],
#          [-0.7578125 ],
#          ...,
#          [-0.78125   ],
#          [-0.78125   ],
#          [-0.77604167]],
#
#         [[-0.74479167],
#          [-0.7421875 ],
#          [-0.76041667],
#          ...,
#          [-0.78125   ],
#          [-0.796875  ],
#          [-0.796875  ]],
#
#         ...,
#
#         [[-0.75520833],
#          [-0.75520833],
#          [-0.7421875 ],
#          ...,
#          [-0.77083333],
#          [-0.75520833],
#          [-0.77604167]],
#
#         [[-0.75260417],
#          [-0.76302083],
#          [-0.75520833],
#          ...,
#          [-0.78125   ],
#          [-0.78385417],
#          [-0.78645833]],
#
#         [[-0.74479167],
#          [-0.76041667],
#          [-0.75260417],
#          ...,
#          [-0.77604167],
#          [-0.77083333],
#          [-0.77864583]]]])

# %%
X_train_gray = np.sum(X_train/3, axis = 3, keepdims = True)
X_test_gray = np.sum(X_test/3, axis = 3, keepdims = True)
X_validation_gray = np.sum(X_validation/3, axis = 3, keepdims = True)

# %%
X_train_gray_norm = (X_train_gray - 128)/128
X_test_gray_norm = (X_test_gray - 128)/128
X_validation_gray_norm = (X_validation_gray - 128)/128

# %%
X_train_gray_norm
# Out:
# array([[[[-0.36197917],
#          [-0.45833333],
#          [-0.65364583],
#          ...,
#          [-0.45572917],
#          [-0.50520833],
#          [-0.54947917]],
#
#         [[-0.38020833],
#          [-0.60677083],
#          [-0.69010417],
#          ...,
#          [-0.59375   ],
#          [-0.63541667],
#          [-0.68489583]],
#
#         [[-0.484375  ],
#          [-0.6953125 ],
#          [-0.6953125 ],
#          ...,
#          [-0.6171875 ],
#          [-0.63802083],
#          [-0.6796875 ]],
#
#         ...,
#
#         [[-0.11197917],
#          [-0.1875    ],
#          [-0.2734375 ],
#          ...,
#          [-0.16145833],
#          [-0.17708333],
#          [-0.14322917]],
#
#         [[-0.078125  ],
#          [-0.22395833],
#          [-0.17708333],
#          ...,
#          [-0.140625  ],
#          [-0.16666667],
#          [-0.17708333]],
#
#         [[ 0.078125  ],
#          [ 0.14583333],
#          [ 0.10416667],
#          ...,
#          [-0.12760417],
#          [-0.1328125 ],
#          [-0.16927083]]],
#
#
#        [[[-0.64583333],
#          [-0.63802083],
#          [-0.6328125 ],
#          ...,
#          [-0.53645833],
#          [-0.56510417],
#          [-0.609375  ]],
#
#         [[-0.6484375 ],
#          [-0.65625   ],
#          [-0.63541667],
#          ...,
#          [-0.5703125 ],
#          [-0.6171875 ],
#          [-0.59635417]],
#
#         [[-0.65104167],
#          [-0.66927083],
#          [-0.64583333],
#          ...,
#          [-0.5859375 ],
#          [-0.63802083],
#          [-0.61197917]],
#
#         ...,
#
#         [[-0.69010417],
#          [-0.69791667],
#          [-0.6953125 ],
#          ...,
#          [-0.6796875 ],
#          [-0.66927083],
#          [-0.67708333]],
#
#         [[-0.67708333],
#          [-0.70833333],
#          [-0.6796875 ],
#          ...,
#          [-0.66927083],
#          [-0.65104167],
#          [-0.66666667]],
#
#         [[-0.70052083],
#          [-0.71354167],
#          [-0.69791667],
#          ...,
#          [-0.66145833],
#          [-0.6796875 ],
#          [-0.66145833]]],
#
#
#        [[[-0.84895833],
#          [-0.859375  ],
#          [-0.85416667],
#          ...,
#          [-0.8046875 ],
#          [-0.82552083],
#          [-0.84114583]],
#
#         [[-0.82552083],
#          [-0.84114583],
#          [-0.8671875 ],
#          ...,
#          [-0.81770833],
#          [-0.83072917],
#          [-0.83854167]],
#
#         [[-0.82552083],
#          [-0.8359375 ],
#          [-0.84895833],
#          ...,
#          [-0.80208333],
#          [-0.80729167],
#          [-0.80989583]],
#
#         ...,
#
#         [[-0.8359375 ],
#          [-0.84375   ],
#          [-0.8515625 ],
#          ...,
#          [-0.83072917],
#          [-0.79947917],
#          [-0.80208333]],
#
#         [[-0.8359375 ],
#          [-0.8359375 ],
#          [-0.85416667],
#          ...,
#          [-0.83072917],
#          [-0.796875  ],
#          [-0.78385417]],
#
#         [[-0.84635417],
#          [-0.84375   ],
#          [-0.85416667],
#          ...,
#          [-0.8359375 ],
#          [-0.8046875 ],
#          [-0.80208333]]],
#
#
#        ...,
#
#
#        [[[-0.67708333],
#          [-0.68489583],
#          [-0.69010417],
#          ...,
#          [ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.9921875 ]],
#
#         [[-0.67708333],
#          [-0.68489583],
#          [-0.6875    ],
#          ...,
#          [ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.9921875 ]],
#
#         [[-0.70052083],
#          [-0.71614583],
#          [-0.734375  ],
#          ...,
#          [ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.9921875 ]],
#
#         ...,
#
#         [[ 0.46875   ],
#          [ 0.46614583],
#          [ 0.46875   ],
#          ...,
#          [ 0.95052083],
#          [ 0.8125    ],
#          [ 0.80729167]],
#
#         [[ 0.49479167],
#          [ 0.5       ],
#          [ 0.51302083],
#          ...,
#          [ 0.88020833],
#          [ 0.48177083],
#          [ 0.44270833]],
#
#         [[ 0.5234375 ],
#          [ 0.52604167],
#          [ 0.54166667],
#          ...,
#          [ 0.953125  ],
#          [ 0.7890625 ],
#          [ 0.78125   ]]],
#
#
#        [[[ 0.03385417],
#          [ 0.04166667],
#          [ 0.04947917],
#          ...,
#          [-0.08854167],
#          [-0.0703125 ],
#          [-0.05989583]],
#
#         [[-0.01822917],
#          [-0.01041667],
#          [-0.0078125 ],
#          ...,
#          [-0.02864583],
#          [-0.015625  ],
#          [ 0.        ]],
#
#         [[-0.04947917],
#          [-0.04427083],
#          [-0.04427083],
#          ...,
#          [ 0.01041667],
#          [ 0.00520833],
#          [ 0.015625  ]],
#
#         ...,
#
#         [[-0.81510417],
#          [-0.8203125 ],
#          [-0.8203125 ],
#          ...,
#          [-0.84114583],
#          [-0.83333333],
#          [-0.84114583]],
#
#         [[-0.828125  ],
#          [-0.83333333],
#          [-0.828125  ],
#          ...,
#          [-0.84375   ],
#          [-0.8359375 ],
#          [-0.8359375 ]],
#
#         [[-0.8359375 ],
#          [-0.83854167],
#          [-0.83072917],
#          ...,
#          [-0.84114583],
#          [-0.83854167],
#          [-0.84375   ]]],
#
#
#        [[[-0.76041667],
#          [-0.765625  ],
#          [-0.765625  ],
#          ...,
#          [-0.7734375 ],
#          [-0.76822917],
#          [-0.75260417]],
#
#         [[-0.75520833],
#          [-0.75520833],
#          [-0.7578125 ],
#          ...,
#          [-0.78125   ],
#          [-0.78125   ],
#          [-0.77604167]],
#
#         [[-0.74479167],
#          [-0.7421875 ],
#          [-0.76041667],
#          ...,
#          [-0.78125   ],
#          [-0.796875  ],
#          [-0.796875  ]],
#
#         ...,
#
#         [[-0.75520833],
#          [-0.75520833],
#          [-0.7421875 ],
#          ...,
#          [-0.77083333],
#          [-0.75520833],
#          [-0.77604167]],
#
#         [[-0.75260417],
#          [-0.76302083],
#          [-0.75520833],
#          ...,
#          [-0.78125   ],
#          [-0.78385417],
#          [-0.78645833]],
#
#         [[-0.74479167],
#          [-0.76041667],
#          [-0.75260417],
#          ...,
#          [-0.77604167],
#          [-0.77083333],
#          [-0.77864583]]]])

# %%
i = random.randint(1, len(X_train_gray))
plt.imshow(X_train_gray[i].squeeze(), cmap = 'gray')
plt.figure()
plt.imshow(X_train[i])
plt.figure()
plt.imshow(X_train_gray_norm[i].squeeze(), cmap = 'gray')

# %% [markdown]
# # TASK #5: UNDERSTAND THE THEORY AND INTUITION BEHIND CONVOLUTIONAL NEURAL NETWORKS

# %% [markdown]
# http://cs.ryerson.ca/~ahaley/vis/conv/flat.html

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # TASK #6: BUILD DEEP CONVOLUTIONAL NEURAL NETWORK MODEL

# %%
from tensorflow.keras import datasets, layers, models
CNN = models.Sequential()

CNN.add(layers.Conv2D(6, (5, 5), activation = 'relu', input_shape = (32, 32, 1)))
CNN.add(layers.AveragePooling2D())

CNN.add(layers.Flatten())

CNN.add(layers.Dense(120, activation = 'relu'))
CNN.add(layers.Dense(84, activation = 'relu'))
CNN.add(layers.Dense(43, activation = 'softmax'))
CNN.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 6)         156
#
#  average_pooling2d (Average  (None, 14, 14, 6)         0
#  Pooling2D)
#
#  flatten (Flatten)           (None, 1176)              0
#
#  dense (Dense)               (None, 120)               141240
#
#  dense_1 (Dense)             (None, 84)                10164
#
#  dense_2 (Dense)             (None, 43)                3655
#
# =================================================================
# Total params: 155215 (606.31 KB)
# Trainable params: 155215 (606.31 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras import datasets, layers, models
CNN = models.Sequential()

CNN.add(layers.Conv2D(6, (5, 5), activation = 'relu', input_shape = (32, 32, 1)))
CNN.add(layers.AveragePooling2D())

CNN.add(layers.Dropout(0.2))

CNN.add(layers.Conv2D(16, (5, 5), activation = 'relu'))
CNN.add(layers.AveragePooling2D())

CNN.add(layers.Flatten())

CNN.add(layers.Dense(120, activation = 'relu'))
CNN.add(layers.Dense(84, activation = 'relu'))
CNN.add(layers.Dense(43, activation = 'softmax'))
CNN.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 28, 28, 6)         156
#
#  average_pooling2d_1 (Avera  (None, 14, 14, 6)         0
#  gePooling2D)
#
#  dropout (Dropout)           (None, 14, 14, 6)         0
#
#  conv2d_2 (Conv2D)           (None, 10, 10, 16)        2416
#
#  average_pooling2d_2 (Avera  (None, 5, 5, 16)          0
#  gePooling2D)
#
#  flatten_1 (Flatten)         (None, 400)               0
#
#  dense_3 (Dense)             (None, 120)               48120
#
#  dense_4 (Dense)             (None, 84)                10164
#
#  dense_5 (Dense)             (None, 43)                3655
#
# =================================================================
# Total params: 64511 (252.00 KB)
# Trainable params: 64511 (252.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # TASK #7: COMPILE AND TRAIN DEEP CNN MODEL

# %%
CNN.compile(optimizer = 'Adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
history = CNN.fit(X_train_gray_norm,
                  y_train,
                  batch_size = 500,
                  epochs = 5,
                  verbose = 1,
                  validation_data = (X_validation_gray_norm, y_validation))
# Out:
# Epoch 1/5
# 70/70 [==============================] - 24s 284ms/step - loss: 3.1420 - accuracy: 0.1799 - val_loss: 2.5779 - val_accuracy: 0.3104
# Epoch 2/5
# 70/70 [==============================] - 18s 262ms/step - loss: 1.7655 - accuracy: 0.4953 - val_loss: 1.4048 - val_accuracy: 0.6161
# Epoch 3/5
# 70/70 [==============================] - 16s 223ms/step - loss: 1.1064 - accuracy: 0.6745 - val_loss: 1.0331 - val_accuracy: 0.7095
# Epoch 4/5
# 70/70 [==============================] - 17s 246ms/step - loss: 0.8405 - accuracy: 0.7538 - val_loss: 0.8245 - val_accuracy: 0.7508
# Epoch 5/5
# 70/70 [==============================] - 18s 261ms/step - loss: 0.6798 - accuracy: 0.8026 - val_loss: 0.7295 - val_accuracy: 0.7955

# %% [markdown]
# For more accuracy, increase epochs

# %%
history = CNN.fit(X_train_gray_norm,
                  y_train,
                  batch_size = 500,
                  epochs = 50,
                  verbose = 1,
                  validation_data = (X_validation_gray_norm, y_validation))
# Out:
# Epoch 1/50
# 70/70 [==============================] - 18s 264ms/step - loss: 0.5862 - accuracy: 0.8297 - val_loss: 0.6697 - val_accuracy: 0.8093
# Epoch 2/50
# 70/70 [==============================] - 18s 257ms/step - loss: 0.5116 - accuracy: 0.8566 - val_loss: 0.6215 - val_accuracy: 0.8166
# Epoch 3/50
# 70/70 [==============================] - 19s 274ms/step - loss: 0.4461 - accuracy: 0.8732 - val_loss: 0.5637 - val_accuracy: 0.8431
# Epoch 4/50
# 70/70 [==============================] - 27s 394ms/step - loss: 0.3926 - accuracy: 0.8884 - val_loss: 0.5310 - val_accuracy: 0.8420
# Epoch 5/50
# 70/70 [==============================] - 20s 284ms/step - loss: 0.3501 - accuracy: 0.9029 - val_loss: 0.5412 - val_accuracy: 0.8583
# Epoch 6/50
# 70/70 [==============================] - 18s 255ms/step - loss: 0.3240 - accuracy: 0.9097 - val_loss: 0.5447 - val_accuracy: 0.8531
# Epoch 7/50
# 70/70 [==============================] - 24s 344ms/step - loss: 0.2984 - accuracy: 0.9147 - val_loss: 0.5058 - val_accuracy: 0.8494
# Epoch 8/50
# 70/70 [==============================] - 25s 351ms/step - loss: 0.2685 - accuracy: 0.9258 - val_loss: 0.4552 - val_accuracy: 0.8651
# Epoch 9/50
# Epoch 47/50
# 70/70 [==============================] - 14s 200ms/step - loss: 0.0435 - accuracy: 0.9870 - val_loss: 0.5464 - val_accuracy: 0.9068
# Epoch 48/50
# 70/70 [==============================] - 14s 202ms/step - loss: 0.0426 - accuracy: 0.9880 - val_loss: 0.5861 - val_accuracy: 0.8955
# Epoch 49/50
# 70/70 [==============================] - 18s 257ms/step - loss: 0.0392 - accuracy: 0.9884 - val_loss: 0.6235 - val_accuracy: 0.8891
# Epoch 50/50
# 70/70 [==============================] - 19s 269ms/step - loss: 0.0397 - accuracy: 0.9878 - val_loss: 0.6164 - val_accuracy: 0.8968

# %% [markdown]
# # TASK #8: ASSESS TRAINED CNN MODEL PERFORMANCE

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
score = CNN.evaluate(X_test_gray_norm, y_test)
print('Test Accuracy: {}'.format(score[1]))
# Out:
# 395/395 [==============================] - 4s 10ms/step - loss: 0.5449 - accuracy: 0.9069
# Test Accuracy: 0.9068883657455444

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %% [markdown]
# For Visualizing Loss

# %%
epochs = range(len(accuracy))
plt.plot(epochs, loss, 'ro', label = 'Training Loss')
plt.plot(epochs, val_loss, 'b', label = 'Validation Loss')
plt.title('Training and Validation loss')
# Out:
# Text(0.5, 1.0, 'Training and Validation loss')

# %% [markdown]
# For Visualizing Accuracy

# %%
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'ro', label = 'Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label = 'Validation Accuracy')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
predicted_probabilities = CNN.predict(X_test_gray_norm)
predicted_classes = np.argmax(predicted_probabilities, axis=1)
y_true = y_test
# Out:
# 395/395 [==============================] - 4s 9ms/step

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, predicted_classes)
plt.figure(figsize = (25, 25))
sns.heatmap(cm, annot = True)
# Out:
# <Axes: >

# %%
L = 5
W = 5

fig, axes = plt.subplots(L, W, figsize = (12, 12))
axes = axes.ravel()

for i in np.arange(0, L*W):
    axes[i].imshow(X_test[i])
    axes[i].set_title('Prediction = {}\n True = {}'.format(predicted_classes[i], y_true[i]))
    axes[i].axis('off')

plt.subplots_adjust(wspace = 1)

# %% [markdown]
# # APPENDIX

# %% [markdown]
# - In this case study, we want to classify images of traffic signs using deep Convolutional Neural Networks (CNNs).
# - The dataset consists of 43 different classes of images.
# - Classes are as listed below:
#   - 0 = Speed limit (20km/h)
#   - 1 = Speed limit (30km/h)
#   - 2 = Speed limit (50km/h)
#   - 3 = Speed limit (60km/h)
#   - 4 = Speed limit (70km/h)
#   - 5 = Speed limit (80km/h)
#   - 6 = End of speed limit (80km/h)
#   - 7 = Speed limit (100km/h)
#   - 8 = Speed limit (120km/h)
#   - 9 = No passing
#   - 10 = No passing for vehicles over 3.5 metric tons
#   - 11 = Right-of-way at the next intersection
#   - 12 = Priority road
#   - 13 = Yield
#   - 14 = Stop
#   - 15 = No vehicles
#   - 16 = Vehicles over 3.5 metric tons prohibited
#   - 17 = No entry
#   - 18 = General caution
#   - 19 = Dangerous curve to the left
#   - 20 = Dangerous curve to the right
#   - 21 = Double curve
#   - 22 = Bumpy road
#   - 23 = Slippery road
#   - 24 = Road narrows on the right
#   - 25 = Road work
#   - 26 = Traffic signals
#   - 27 = Pedestrians
#   - 28 = Children crossing
#   - 29 = Bicycles crossing
#   - 30 = Beware of ice/snow
#   - 31 = Wild animals crossing
#   - 32 = End of all speed and passing limits
#   - 33 = Turn right ahead
#   - 34 = Turn left ahead
#   - 35 = Ahead only
#   - 36 = Go straight or right
#   - 37 = Go straight or left
#   - 38 = Keep right
#   - 39 = Keep left
#   - 40 = Roundabout mandatory
#   - 41 = End of no passing
#   - 42 = End of no passing by vehicles over 3.5 metric tons
#
# - Citation
# J. Stallkamp, M. Schlipsing, J. Salmen, and C. Igel. The German Traffic Sign Recognition Benchmark: A multi-class classification competition. In Proceedings of the IEEE International Joint Conference on Neural Networks, pages 1453–1460. 2011.
# @inproceedings{Stallkamp-IJCNN-2011, author = {Johannes Stallkamp and Marc Schlipsing and Jan Salmen and Christian Igel}, booktitle = {IEEE International Joint Conference on Neural Networks}, title = {The {G}erman {T}raffic {S}ign {R}ecognition {B}enchmark: A multi-class classification competition}, year = {2011}, pages = {1453--1460} }
